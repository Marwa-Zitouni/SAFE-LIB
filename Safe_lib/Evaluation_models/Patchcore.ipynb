# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install "anomalib[vlm_clip]"
# Out:
# Collecting anomalib[vlm_clip]
#   Downloading anomalib-2.2.0-py3-none-any.whl.metadata (33 kB)
# WARNING: anomalib 2.2.0 does not provide the extra 'vlm-clip'
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.12/dist-packages (from anomalib[vlm_clip]) (0.17.0)
# Requirement already satisfied: einops>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from anomalib[vlm_clip]) (0.8.1)
# Collecting freia>=0.2 (from anomalib[vlm_clip])
#   Downloading FrEIA-0.2.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Collecting imagecodecs (from anomalib[vlm_clip])
#   Downloading imagecodecs-2025.11.11-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Collecting jsonargparse>=4.27.7 (from jsonargparse[signatures]>=4.27.7->anomalib[vlm_clip])
#   Downloading jsonargparse-4.44.0-py3-none-any.whl.metadata (12 kB)
# Collecting kornia>=0.6.6 (from anomalib[vlm_clip])
#   Downloading kornia-0.8.2-py2.py3-none-any.whl.metadata (18 kB)
# Collecting lightning-utilities (from anomalib[vlm_clip])
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting lightning>=2.2 (from anomalib[vlm_clip])
#   Downloading lightning-2.6.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.4.3 in /usr/local/lib/python3.12/dist-packages (from anomalib[vlm_clip]) (3.10.0)
# Requirement already satisfied: omegaconf>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from anomalib[vlm_clip]) (2.3.0)
# Requirement already satisfied: opencv-python>=4.5.3.56 in /usr/local/lib/python3.12/dist-packages (from anomalib[vlm_clip]) (4.12.0.88)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from anomalib[vlm_clip]) (2.2.2)
# Requirement already satisfied: pillow>=10.1.0 in /usr/local/lib/python3.12/dist-packages (from anomalib[vlm_clip]) (11.3.0)
# Collecting rich-argparse (from anomalib[vlm_clip])
#   Downloading rich_argparse-1.7.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: rich>=13.5.2 in /usr/local/lib/python3.12/dist-packages (from anomalib[vlm_clip]) (13.9.4)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from anomalib[vlm_clip]) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from anomalib[vlm_clip]) (1.6.1)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from anomalib[vlm_clip]) (2025.10.16)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from anomalib[vlm_clip]) (1.0.22)
# Collecting torchmetrics>=1.8.2 (from anomalib[vlm_clip])
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from freia>=0.2->anomalib[vlm_clip]) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from freia>=0.2->anomalib[vlm_clip]) (1.16.3)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from freia>=0.2->anomalib[vlm_clip]) (2.9.0+cu126)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.12/dist-packages (from jsonargparse>=4.27.7->jsonargparse[signatures]>=4.27.7->anomalib[vlm_clip]) (6.0.3)
# Collecting typeshed-client>=2.8.2 (from jsonargparse[signatures]>=4.27.7->anomalib[vlm_clip])
#   Downloading typeshed_client-2.8.2-py3-none-any.whl.metadata (9.9 kB)
# Collecting kornia_rs>=0.1.9 (from kornia>=0.6.6->anomalib[vlm_clip])
#   Downloading kornia_rs-0.1.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia>=0.6.6->anomalib[vlm_clip]) (25.0)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib[vlm_clip]) (2025.3.0)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.2->anomalib[vlm_clip]) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.2->anomalib[vlm_clip]) (4.15.0)
# Collecting pytorch-lightning (from lightning>=2.2->anomalib[vlm_clip])
#   Downloading pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities->anomalib[vlm_clip]) (75.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib[vlm_clip]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib[vlm_clip]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib[vlm_clip]) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib[vlm_clip]) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib[vlm_clip]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.4.3->anomalib[vlm_clip]) (2.9.0.post0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf>=2.1.1->anomalib[vlm_clip]) (4.9.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.0->anomalib[vlm_clip]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.0->anomalib[vlm_clip]) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.5.2->anomalib[vlm_clip]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.5.2->anomalib[vlm_clip]) (2.19.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->anomalib[vlm_clip]) (3.6)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->anomalib[vlm_clip]) (2.37.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->anomalib[vlm_clip]) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->anomalib[vlm_clip]) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->anomalib[vlm_clip]) (3.6.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm->anomalib[vlm_clip]) (0.24.0+cu126)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm->anomalib[vlm_clip]) (0.36.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm->anomalib[vlm_clip]) (0.7.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib[vlm_clip]) (3.13.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.5.2->anomalib[vlm_clip]) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4.3->anomalib[vlm_clip]) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (3.5.0)
# Requirement already satisfied: importlib_resources>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from typeshed-client>=2.8.2->jsonargparse[signatures]>=4.27.7->anomalib[vlm_clip]) (6.5.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->anomalib[vlm_clip]) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm->anomalib[vlm_clip]) (1.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib[vlm_clip]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib[vlm_clip]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib[vlm_clip]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib[vlm_clip]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib[vlm_clip]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib[vlm_clip]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.2->anomalib[vlm_clip]) (1.22.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->freia>=0.2->anomalib[vlm_clip]) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm->anomalib[vlm_clip]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm->anomalib[vlm_clip]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm->anomalib[vlm_clip]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm->anomalib[vlm_clip]) (2025.11.12)
# Downloading jsonargparse-4.44.0-py3-none-any.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.8/241.8 kB 11.6 MB/s eta 0:00:00
# Downloading kornia-0.8.2-py2.py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 40.8 MB/s eta 0:00:00
# Downloading lightning-2.6.0-py3-none-any.whl (845 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 55.9 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 53.0 MB/s eta 0:00:00
# Downloading anomalib-2.2.0-py3-none-any.whl (851 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 851.8/851.8 kB 44.5 MB/s eta 0:00:00
# Downloading imagecodecs-2025.11.11-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 89.7 MB/s eta 0:00:00
# Downloading rich_argparse-1.7.2-py3-none-any.whl (25 kB)
# Downloading kornia_rs-0.1.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 104.9 MB/s eta 0:00:00
# Downloading typeshed_client-2.8.2-py3-none-any.whl (760 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.5/760.5 kB 51.5 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 62.8 MB/s eta 0:00:00
# Building wheels for collected packages: freia
#   Building wheel for freia (setup.py) ... done
#   Created wheel for freia: filename=FrEIA-0.2-py3-none-any.whl size=42763 sha256=692b2759da28a43af72b919d0e11a3a1925ea86e81408787a9eb67ebd186e7d1
#   Stored in directory: /root/.cache/pip/wheels/ae/40/63/f30f17a00a5c53f982c5c222995b53fe1ee510d2ea13b00856
# Successfully built freia
# Installing collected packages: typeshed-client, lightning-utilities, kornia_rs, jsonargparse, imagecodecs, rich-argparse, torchmetrics, kornia, freia, pytorch-lightning, lightning, anomalib
# Successfully installed anomalib-2.2.0 freia-0.2 imagecodecs-2025.11.11 jsonargparse-4.44.0 kornia-0.8.2 kornia_rs-0.1.10 lightning-2.6.0 lightning-utilities-0.15.2 pytorch-lightning-2.6.0 rich-argparse-1.7.2 torchmetrics-1.8.2 typeshed-client-2.8.2

# %%
# !pip install open-clip-torch
# Out:
# Collecting open-clip-torch
#   Downloading open_clip_torch-3.2.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from open-clip-torch) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from open-clip-torch) (0.24.0+cu126)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from open-clip-torch) (2025.11.3)
# Collecting ftfy (from open-clip-torch)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from open-clip-torch) (4.67.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from open-clip-torch) (0.36.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from open-clip-torch) (0.7.0)
# Requirement already satisfied: timm>=1.0.17 in /usr/local/lib/python3.12/dist-packages (from open-clip-torch) (1.0.22)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm>=1.0.17->open-clip-torch) (6.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->open-clip-torch) (3.5.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->open-clip-torch) (0.2.14)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open-clip-torch) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open-clip-torch) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open-clip-torch) (1.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->open-clip-torch) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->open-clip-torch) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0->open-clip-torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->open-clip-torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->open-clip-torch) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->open-clip-torch) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->open-clip-torch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->open-clip-torch) (2025.11.12)
# Downloading open_clip_torch-3.2.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 33.2 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: ftfy, open-clip-torch
# Successfully installed ftfy-6.3.1 open-clip-torch-3.2.0

# %%
from anomalib.data import MVTecAD
from anomalib.models import Patchcore
from anomalib.engine import Engine

# %%
import os, glob
from PIL import Image

base = "/content/drive/MyDrive/Colab Notebooks/data/battery_small"
folders = [
    f"{base}/train/good",
    f"{base}/test/good",
    f"{base}/test/overheat",
    f"{base}/test/thermal_imbalance",
    f"{base}/test/spatial_tape",
    f"{base}/ground_truth/overheat",
    f"{base}/ground_truth/thermal_imbalance",
    f"{base}/ground_truth/spatial_tape"
]

for folder in folders:
    if not os.path.isdir(folder):
        continue
    for p in glob.glob(os.path.join(folder, "*.jpg")) + glob.glob(os.path.join(folder, "*.JPG")):
        out = os.path.splitext(p)[0] + ".png"
        if not os.path.exists(out):
            Image.open(p).convert("RGB").save(out)
print("Done converting to PNG.")
# Out:
# Done converting to PNG.

# %%
# Initialize model and data
datamodule = MVTecAD(
    root="/content/drive/MyDrive/Colab Notebooks/data",
    category="battery_small",       # folder under your_dataset/

)
datamodule.setup()
print("Train samples:", len(datamodule.train_data.samples))
print("Test samples:", len(datamodule.test_data.samples))
model = Patchcore(
    backbone="wide_resnet50_2",
    layers=["layer2", "layer3"],
    coreset_sampling_ratio=0.1
)
# Out:
# Train samples: 337
# Test samples: 48

# %%
# Train using the Engine
engine = Engine(enable_progress_bar=False)
engine.fit(model=model, datamodule=datamodule)
# Out:
# INFO:lightning_fabric.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:lightning_fabric.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/core/optimizer.py:183: `LightningModule.configure_optimizers` returned `None`, this fit will run with no optimizer
# ┏━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name           ┃ Type           ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ pre_processor  │ PreProcessor   │      0 │ train │     0 │
# │ 1 │ post_processor │ PostProcessor  │      0 │ train │     0 │
# │ 2 │ evaluator      │ Evaluator      │      0 │ train │     0 │
# │ 3 │ model          │ PatchcoreModel │ 24.9 M │ train │     0 │
# └───┴────────────────┴────────────────┴────────┴───────┴───────┘
# Trainable params: 24.9 M
# Non-trainable params: 0
# Total params: 24.9 M
# Total estimated model params size (MB): 99
# Modules in train mode: 19
# Modules in eval mode: 174
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/loops/fit_loop.py:534: Found 174 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If this is intentional, you can ignore this warning.
# Selecting Coreset Indices.:  89%|████████▊ | 30569/34508 [02:50<00:22, 175.28it/s]

# %%
# Get predictions
predictions = engine.predict(model=model, datamodule=datamodule)
# Out:
# WARNING:anomalib.engine.engine:ckpt_path is not provided. Model weights will not be loaded.
# INFO:lightning_fabric.utilities.rank_zero:The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: Evaluator, ImageVisualizer, PostProcessor, PreProcessor
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %%
test_metrics = engine.test(model=model, datamodule=datamodule)
print(test_metrics)  # e.g. {'image_auroc': ..., 'pixel_auroc': ..., ...}
# Out:
# INFO:lightning_fabric.utilities.rank_zero:The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: Evaluator, ImageVisualizer, PostProcessor, PreProcessor
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │            1.0            │
# │       image_F1Score       │    0.9984917044639587     │
# │        pixel_AUROC        │    0.7687110900878906     │
# │       pixel_F1Score       │    0.6685149073600769     │
# └───────────────────────────┴───────────────────────────┘
# [{'image_AUROC': 1.0, 'image_F1Score': 0.9984917044639587, 'pixel_AUROC': 0.7687110900878906, 'pixel_F1Score': 0.6685149073600769}]
